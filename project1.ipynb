# %%
#Final project

# %%
#this is the notebook that will deal with all the skills I learned through this course

# %%
#Data science language
#-python
#-R
#-SQL
#-Julia
#-Scala

# %%
## Data Science Libraries
- NumPy
- Pandas
- Matplotlib
- scikit-learn
- TensorFlow / Keras
- PyTorch
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 ## Data Science Libraries
# ----> 2 - NumPy
#       3 - Pandas
#       4 - Matplotlib
#
# NameError: name 'NumPy' is not defined

# %%
#Data Science Libraries
#- NumPy
#- Pandas
#- Matplotlib
#- scikit-learn
#- TensorFlow
#- PyTorch

# %%
## Arithmetic Expression Examples
##Below are simple code examples demonstrating arithmetic operations and unit conversion.

# %%
a = 7
b = 5
product = a * b
sum_result = a + b
product, sum_result
# Out:
# (35, 12)

# %%
def minutes_to_hours(minutes):
    hours = minutes // 60
    remaining_minutes = minutes % 60
    return f"{minutes} minutes = {hours} hour(s) and {remaining_minutes} minute(s)"
minutes_to_hours(135)
# Out:
# '135 minutes = 2 hour(s) and 15 minute(s)'

# %%
#Objectives
#1. Demonstrate ability to create markdown and code cells in a notebook.
#2. Provide simple arithmetic and conversion code examples.
#3. Share the completed notebook publicly on GitHub for review.

# %%
#Ghattamaneni Prudhvi
